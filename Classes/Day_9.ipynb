# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiamiyu1/Python-for-Data-Science-and-Analytics/blob/main/Classes/Day_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# dataframe 2d data structure with different columns
#
# Ways of creating pandas df - dict, array(specify col_name in a alist), list, read
#
# Df Attr - index, values, shape, dtypes, axes, sum, max
#
# Df method info, head, tail, describe, reset_index(inplace)
#
# Indexing - iloc, loc,
#
# Filtering - combining conditions
#
# Inseting/Deleting rows-columns kk.loc['R3'] = [10,11,12]
#
# del col, drop col
#
# Missing data - check, fillna, drop

# %%
import numpy as np
import pandas as pd

# %%
series = pd.Series([12,34,567,78])
series
# Out:
# 0     12
# 1     34
# 2    567
# 3     78
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
state = pd.Series(['Osun', 'Oyo', 'Lagos', 'Nasarawa'])
state
# Out:
# 0        Osun
# 1         Oyo
# 2       Lagos
# 3    Nasarawa
# dtype: object

# %%
state = pd.Series({'Osun':'Osogbo', 'Oyo':'Ibadan', 'Lagos':'Ikeja', 'Nasarawa':'Lafia'})
state
# Out:
# Osun        Osogbo
# Oyo         Ibadan
# Lagos        Ikeja
# Nasarawa     Lafia
# dtype: object

# %%
pd.DataFrame(np.arange(1,10).reshape(3,3), index=['R1', 'R2', 'R3'])
# Out:
#     0  1  2
# R1  1  2  3
# R2  4  5  6
# R3  7  8  9

# %%
df = pd.DataFrame(np.arange(1,10).reshape(3,3), index=['R1', 'R2', 'R3'], columns=['C1', 'C2', 'C3'])
df
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9

# %%
df.loc['R3', 'C3']
# Out:
# 9

# %%
df.loc['R2', 'C2']
# Out:
# 5

# %%
df.loc[:,'C2']
# Out:
# R1    2
# R2    5
# R3    8
# Name: C2, dtype: int64

# %%
df.loc['R2':, 'C2':]
# Out:
#     C2  C3
# R2   5   6
# R3   8   9

# %%
df
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9

# %%
df.iloc[0]
# Out:
# C1    1
# C2    2
# C3    3
# Name: R1, dtype: int64

# %%
df.iloc[2]
# Out:
# C1    7
# C2    8
# C3    9
# Name: R3, dtype: int64

# %%
df.C2
# Out:
# R1    2
# R2    5
# R3    8
# Name: C2, dtype: int64

# %%
df[df>=5]
# Out:
#      C1   C2   C3
# R1  NaN  NaN  NaN
# R2  NaN  5.0  6.0
# R3  7.0  8.0  9.0

# %%
df
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9

# %%
df.loc['R4'] = [10, 11,12]
df
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9
# R4  10  11  12

# %%
df.loc['C4'] = [15,25,30]

# %%
df
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9
# R4  10  11  12
# C4  15  25  30

# %%
df['C4'] = [12,45,21,45,10]
df
# Out:
#     C1  C2  C3  C4
# R1   1   2   3  12
# R2   4   5   6  45
# R3   7   8   9  21
# R4  10  11  12  45
# C4  15  25  30  10

# %%
df.loc['R4', 'C4'] = 46
df
# Out:
#     C1  C2  C3  C4
# R1   1   2   3  12
# R2   4   5   6  45
# R3   7   8   9  21
# R4  10  11  12  46
# C4  15  25  30  10

# %%
# Drop row/column
df.drop('C4', axis=1)
# Out:
#     C1  C2  C3
# R1   1   2   3
# R2   4   5   6
# R3   7   8   9
# R4  10  11  12
# C4  15  25  30

# %%
# Drop row/column
df = df.drop('C4')
df
# Out:
#     C1  C2  C3  C4
# R1   1   2   3  12
# R2   4   5   6  45
# R3   7   8   9  21
# R4  10  11  12  46

# %%
#Creating a df
name = ['Azeez', 'Kauthat', 'Jimoh', 'Debby', 'Tunde']
id = [0,1,2,3,4]
department = ['Chemistry', 'Mathematics', 'English', 'Computer', 'Data']
gp = [4.5, 2.9, 3.0, 5.0, 1.1]
student = pd.DataFrame({'ID':id, "Name":name, "Department":department, "CGPA":gp})
student
# Out:
#    ID     Name   Department  CGPA
# 0   0    Azeez    Chemistry   4.5
# 1   1  Kauthat  Mathematics   2.9
# 2   2    Jimoh      English   3.0
# 3   3    Debby     Computer   5.0
# 4   4    Tunde         Data   1.1

# %%
student.loc[4]
# Out:
# ID                4
# Name          Tunde
# Department     Data
# CGPA            1.1
# Name: 4, dtype: object

# %%
student.query('CGPA >= 3.0')
# Out:
#    ID   Name Department  CGPA
# 0   0  Azeez  Chemistry   4.5
# 2   2  Jimoh    English   3.0
# 3   3  Debby   Computer   5.0

# %%
student['Department']
# Out:
# 0      Chemistry
# 1    Mathematics
# 2        English
# 3       Computer
# 4           Data
# Name: Department, dtype: object

# %%
student[['Department', 'CGPA', 'ID']]
# Out:
#     Department  CGPA  ID
# 0    Chemistry   4.5   0
# 1  Mathematics   2.9   1
# 2      English   3.0   2
# 3     Computer   5.0   3
# 4         Data   1.1   4

# %%
student.to_csv('student.csv', index=False)
